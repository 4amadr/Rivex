# %%
from itertools import count
import requests
import pytz
import json
import csv
from datetime import datetime, timedelta
import time
import base64
import os
import sys
from dotenv import load_dotenv
import argparse
import callix_token_db
from callix_token_db import CallixDB
load_dotenv()

dia = int(datetime.today().day)
ontem = dia - 1
mes = int(datetime.today().month)
ano = int(datetime.today().year)
dia_teste = ontem - 5

print(dia_teste)
# Out:
# Conectado ao banco de dados!
# 820303e8-b991-4320-85d5-6169a848d77b essencecontech.callix.com.br
# 820303e8-b991-4320-85d5-6169a848d77b
# essencecontech.callix.com.br
# Banco de dados fechado
# 19

# %%
def chamadas_completas(ano, mes, dia):
        '''Função para buscar as chamadas completas de um cliente'''

        data_inicio = f"{ano}-{mes:02d}-{dia:02d}T00:00:00.000Z"
        data_fim = f"{ano}-{mes:02d}-{dia:02d}T23:59:59.999Z"

        # tratar a requisição
        # alguns clientes vem com nome capitalizado e sem o sufixo "contech"
        #link_tratado = f"{cliente_link.lower().replace(' ', '')}contech"

        url = f"https://investmaiscontech.callix.com.br/api/v1/campaign_completed_calls"

        #print(f'Cliente selecionado {link_tratado}')
        print(f'coletando dados do dia {dia}/{mes}/{ano}')

        querystring = {
        "filter[started_at]": f"{data_inicio},{data_fim}"
    }
        
        headers = {
            "Content-Type": "application/json",
            "Authorization": "Bearer c2195761-e30a-4880-b845-2f55ad722ea3"
        }
        
        
        try:
            response = requests.request("GET", url, headers=headers, params=querystring)

            
            
            if response.status_code == 200:
                chamadas_completas = response.json()
                print("Chamadas completas coletadas com sucesso!")
                print(chamadas_completas)
                return chamadas_completas
            else:
                print(f"Erro ao buscar as chamadas completas: {response.status_code}")
                print(f" {response.text}")
                return None
        except Exception as e:
            print(f"Erro ao buscar as chamadas completas: {e}")
            return None

# %%
chamadas_completas(ano, mes, dia_teste)
# Out:
# coletando dados do dia 19/11/2025
# Chamadas completas coletadas com sucesso!
# {'meta': {'count': 748}, 'links': {'first': '/api/v1/campaign_completed_calls?filter%5Bstarted_at%5D=2025-11-19T00%3A00%3A00.000Z%2C2025-11-19T23%3A59%3A59.999Z&page%5Blimit%5D=100&page%5Boffset%5D=0', 'last': '/api/v1/campaign_completed_calls?filter%5Bstarted_at%5D=2025-11-19T00%3A00%3A00.000Z%2C2025-11-19T23%3A59%3A59.999Z&page%5Blimit%5D=100&page%5Boffset%5D=700', 'next': '/api/v1/campaign_completed_calls?filter%5Bstarted_at%5D=2025-11-19T00%3A00%3A00.000Z%2C2025-11-19T23%3A59%3A59.999Z&page%5Blimit%5D=100&page%5Boffset%5D=100'}, 'data': [{'type': 'campaign_completed_calls', 'id': '11019463', 'attributes': {'started_at': '2025-11-19T11:02:51.005000Z', 'ended_at': '2025-11-19T11:03:17.385000Z', 'duration': 26, 'destination_phone': '+5531987221750', 'protocol': 536120, 'answered_at': '2025-11-19T11:03:09.425000Z', 'hangup_cause': 1, 'service_duration': 8, 'has_audio': True, 'call_recording_status': 1, 'audio_link': '/api/v1/campaign_completed_calls/11019463/audio'}, 'relationships': {'campaign': {'data': {'type': 'campaigns', 'id': '5'}, 'links': {'self': '/api/v1/campaign_completed_calls/11019463/relationships/campaign', 'related': '/api/v1/campaign_completed_calls/11019463/campaign'}}, 'campaign_list': {'data': {'type': 'campaign_lists', 'id': '650'}, 'links': {'self': '/api/v1/campaign_completed_calls/11019463/relationships/campaign_list', 'related': '/api/v1/campaign_completed_calls/11019463/campaign_list'}}, 'campaign_contact': {'data': {'type': 'campaign_contacts', 'id': '9168404'}, 'links': {'self': '/api/v1/campaign_completed_calls/11019463/relationships/campaign_contact', 'related': '/api/v1/campaign_completed_calls/11019463/campaign_contact'}}, 'customer': {'links': {'self': '/api/v1/campaign_completed_calls/11019463/relationships/customer', 'related': '/api/v1/campaign_completed_calls/11019463/customer'}}, 'qualification': {'data': {'type': 'qualifications', 'id': '30001'}, 'links': {'self': '/api/v1/campaign_completed_calls/11019463/relationships/qualification', 'related': '/api/v1/campaign_completed_calls/11019463/qualification'}}, 'agent': {'data': {'type': 'users', 'id': '5'}, 'links': {'self': '/api/v1/campaign_completed_calls/11019463/relationships/agent', 'related': '/api/v1/campaign_completed_calls/11019463/agent'}}, 'transcriptions': {'data': [], 'links': {'self': '/api/v1/campaign_completed_calls/11019463/relationships/transcriptions', 'related': '/api/v1/campaign_completed_calls/11019463/transcriptions'}}, 'tags': {'data': [], 'links': {'self': '/api/v1/campaign_completed_calls/11019463/relationships/tags', 'related': '/api/v1/campaign_completed_calls/11019463/tags'}}}, 'links': {'self': '/api/v1/campaign_completed_calls/11019463'}}, {'type': 'campaign_completed_calls', 'id': '11019474', 'attributes': {'started_at': '2025-11-19T11:02:48.997000Z', 'ended_at': '2025-11-19T11:03:41.197000Z', 'duration': 52, 'destination_phone': '+5551996026495', 'protocol': 536119, 'answered_at': '2025-11-19T11:03:05.657000Z', 'hangup_cause': 2, 'service_duration': 36, 'has_audio': True, 'call_recording_status': 1, 'audio_link': '/api/v1/campaign_completed_calls/11019474/audio'}, 'relationships': {'campaign': {'data': {'type': 'campaigns', 'id': '5'}, 'links': {'self': '/api/v1/campaign_completed_calls/11019474/relationships/campaign', 'related': '/api/v1/campaign_completed_calls/11019474/campaign'}}, 'campaign_list': {'data': {'type': 'campaign_lists', 'id': '650'}, 'links': {'self': '/api/v1/campaign_completed_calls/11019474/relationships/campaign_list', 'related': '/api/v1/campaign_completed_calls/11019474/campaign_list'}}, 'campaign_contact': {'data': {'type': 'campaign_contacts', 'id': '9168394'}, 'links': {'self': '/api/v1/campaign_completed_calls/11019474/relationships/campaign_contact', 'related': '/api/v1/campaign_completed_calls/11019474/campaign_contact'}}, 'customer': {'links': {'self': '/api/v1/campaign_completed_calls/11019474/relationships/customer', 'related': '/api/v1/campaign_completed_calls/11019474/custo ...
# {'meta': {'count': 748},
#  'links': {'first': '/api/v1/campaign_completed_calls?filter%5Bstarted_at%5D=2025-11-19T00%3A00%3A00.000Z%2C2025-11-19T23%3A59%3A59.999Z&page%5Blimit%5D=100&page%5Boffset%5D=0',
#   'last': '/api/v1/campaign_completed_calls?filter%5Bstarted_at%5D=2025-11-19T00%3A00%3A00.000Z%2C2025-11-19T23%3A59%3A59.999Z&page%5Blimit%5D=100&page%5Boffset%5D=700',
#   'next': '/api/v1/campaign_completed_calls?filter%5Bstarted_at%5D=2025-11-19T00%3A00%3A00.000Z%2C2025-11-19T23%3A59%3A59.999Z&page%5Blimit%5D=100&page%5Boffset%5D=100'},
#  'data': [{'type': 'campaign_completed_calls',
#    'id': '11019463',
#    'attributes': {'started_at': '2025-11-19T11:02:51.005000Z',
#     'ended_at': '2025-11-19T11:03:17.385000Z',
#     'duration': 26,
#     'destination_phone': '+5531987221750',
#     'protocol': 536120,
#     'answered_at': '2025-11-19T11:03:09.425000Z',
#     'hangup_cause': 1,
#     'service_duration': 8,
#     'has_audio': True,
#     'call_recording_status': 1,
#     'audio_link': '/api/v1/campaign_completed_calls/11019463/audio'},
#    'relationships': {'campaign': {'data': {'type': 'campaigns', 'id': '5'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019463/relationships/campaign',
#       'related': '/api/v1/campaign_completed_calls/11019463/campaign'}},
#     'campaign_list': {'data': {'type': 'campaign_lists', 'id': '650'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019463/relationships/campaign_list',
#       'related': '/api/v1/campaign_completed_calls/11019463/campaign_list'}},
#     'campaign_contact': {'data': {'type': 'campaign_contacts',
#       'id': '9168404'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019463/relationships/campaign_contact',
#       'related': '/api/v1/campaign_completed_calls/11019463/campaign_contact'}},
#     'customer': {'links': {'self': '/api/v1/campaign_completed_calls/11019463/relationships/customer',
#       'related': '/api/v1/campaign_completed_calls/11019463/customer'}},
#     'qualification': {'data': {'type': 'qualifications', 'id': '30001'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019463/relationships/qualification',
#       'related': '/api/v1/campaign_completed_calls/11019463/qualification'}},
#     'agent': {'data': {'type': 'users', 'id': '5'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019463/relationships/agent',
#       'related': '/api/v1/campaign_completed_calls/11019463/agent'}},
#     'transcriptions': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11019463/relationships/transcriptions',
#       'related': '/api/v1/campaign_completed_calls/11019463/transcriptions'}},
#     'tags': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11019463/relationships/tags',
#       'related': '/api/v1/campaign_completed_calls/11019463/tags'}}},
#    'links': {'self': '/api/v1/campaign_completed_calls/11019463'}},
#   {'type': 'campaign_completed_calls',
#    'id': '11019474',
#    'attributes': {'started_at': '2025-11-19T11:02:48.997000Z',
#     'ended_at': '2025-11-19T11:03:41.197000Z',
#     'duration': 52,
#     'destination_phone': '+5551996026495',
#     'protocol': 536119,
#     'answered_at': '2025-11-19T11:03:05.657000Z',
#     'hangup_cause': 2,
#     'service_duration': 36,
#     'has_audio': True,
#     'call_recording_status': 1,
#     'audio_link': '/api/v1/campaign_completed_calls/11019474/audio'},
#    'relationships': {'campaign': {'data': {'type': 'campaigns', 'id': '5'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019474/relationships/campaign',
#       'related': '/api/v1/campaign_completed_calls/11019474/campaign'}},
#     'campaign_list': {'data': {'type': 'campaign_lists', 'id': '650'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019474/relationships/campaign_list',
#       'related': '/api/v1/campaign_completed_calls/11019474/campaign_list'}},
#     'campaign_contact': {'data': {'type': 'campaign_contacts',
#       'id': '9168394'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019474/relationships/campaign_contact',
#       'related': '/api/v1/campaign_completed_calls/11019474/campaign_contact'}},
#     'customer': {'links': {'self': '/api/v1/campaign_completed_calls/11019474/relationships/customer',
#       'related': '/api/v1/campaign_completed_calls/11019474/customer'}},
#     'qualification': {'data': {'type': 'qualifications', 'id': '30001'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019474/relationships/qualification',
#       'related': '/api/v1/campaign_completed_calls/11019474/qualification'}},
#     'agent': {'data': {'type': 'users', 'id': '10'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019474/relationships/agent',
#       'related': '/api/v1/campaign_completed_calls/11019474/agent'}},
#     'transcriptions': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11019474/relationships/transcriptions',
#       'related': '/api/v1/campaign_completed_calls/11019474/transcriptions'}},
#     'tags': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11019474/relationships/tags',
#       'related': '/api/v1/campaign_completed_calls/11019474/tags'}}},
#    'links': {'self': '/api/v1/campaign_completed_calls/11019474'}},
#   {'type': 'campaign_completed_calls',
#    'id': '11019559',
#    'attributes': {'started_at': '2025-11-19T11:04:59.006000Z',
#     'ended_at': '2025-11-19T11:05:22.226000Z',
#     'duration': 23,
#     'destination_phone': '+5532999924348',
#     'protocol': 536122,
#     'answered_at': '2025-11-19T11:05:18.266000Z',
#     'hangup_cause': 1,
#     'service_duration': 4,
#     'has_audio': True,
#     'call_recording_status': 1,
#     'audio_link': '/api/v1/campaign_completed_calls/11019559/audio'},
#    'relationships': {'campaign': {'data': {'type': 'campaigns', 'id': '5'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019559/relationships/campaign',
#       'related': '/api/v1/campaign_completed_calls/11019559/campaign'}},
#     'campaign_list': {'data': {'type': 'campaign_lists', 'id': '650'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019559/relationships/campaign_list',
#       'related': '/api/v1/campaign_completed_calls/11019559/campaign_list'}},
#     'campaign_contact': {'data': {'type': 'campaign_contacts',
#       'id': '9168515'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019559/relationships/campaign_contact',
#       'related': '/api/v1/campaign_completed_calls/11019559/campaign_contact'}},
#     'customer': {'links': {'self': '/api/v1/campaign_completed_calls/11019559/relationships/customer',
#       'related': '/api/v1/campaign_completed_calls/11019559/customer'}},
#     'qualification': {'data': {'type': 'qualifications', 'id': '30001'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019559/relationships/qualification',
#       'related': '/api/v1/campaign_completed_calls/11019559/qualification'}},
#     'agent': {'data': {'type': 'users', 'id': '10'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019559/relationships/agent',
#       'related': '/api/v1/campaign_completed_calls/11019559/agent'}},
#     'transcriptions': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11019559/relationships/transcriptions',
#       'related': '/api/v1/campaign_completed_calls/11019559/transcriptions'}},
#     'tags': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11019559/relationships/tags',
#       'related': '/api/v1/campaign_completed_calls/11019559/tags'}}},
#    'links': {'self': '/api/v1/campaign_completed_calls/11019559'}},
#   {'type': 'campaign_completed_calls',
#    'id': '11019598',
#    'attributes': {'started_at': '2025-11-19T11:04:30.986000Z',
#     'ended_at': '2025-11-19T11:06:36.566000Z',
#     'duration': 125,
#     'destination_phone': '+5551993852483',
#     'protocol': 536121,
#     'answered_at': '2025-11-19T11:05:03.586000Z',
#     'hangup_cause': 1,
#     'service_duration': 93,
#     'has_audio': True,
#     'call_recording_status': 1,
#     'audio_link': '/api/v1/campaign_completed_calls/11019598/audio'},
#    'relationships': {'campaign': {'data': {'type': 'campaigns', 'id': '5'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019598/relationships/campaign',
#       'related': '/api/v1/campaign_completed_calls/11019598/campaign'}},
#     'campaign_list': {'data': {'type': 'campaign_lists', 'id': '650'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019598/relationships/campaign_list',
#       'related': '/api/v1/campaign_completed_calls/11019598/campaign_list'}},
#     'campaign_contact': {'data': {'type': 'campaign_contacts',
#       'id': '9168486'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019598/relationships/campaign_contact',
#       'related': '/api/v1/campaign_completed_calls/11019598/campaign_contact'}},
#     'customer': {'links': {'self': '/api/v1/campaign_completed_calls/11019598/relationships/customer',
#       'related': '/api/v1/campaign_completed_calls/11019598/customer'}},
#     'qualification': {'data': {'type': 'qualifications', 'id': '30005'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019598/relationships/qualification',
#       'related': '/api/v1/campaign_completed_calls/11019598/qualification'}},
#     'agent': {'data': {'type': 'users', 'id': '5'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019598/relationships/agent',
#       'related': '/api/v1/campaign_completed_calls/11019598/agent'}},
#     'transcriptions': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11019598/relationships/transcriptions',
#       'related': '/api/v1/campaign_completed_calls/11019598/transcriptions'}},
#     'tags': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11019598/relationships/tags',
#       'related': '/api/v1/campaign_completed_calls/11019598/tags'}}},
#    'links': {'self': '/api/v1/campaign_completed_calls/11019598'}},
#   {'type': 'campaign_completed_calls',
#    'id': '11019640',
#    'attributes': {'started_at': '2025-11-19T11:07:18.989000Z',
#     'ended_at': '2025-11-19T11:08:42.329000Z',
#     'duration': 83,
#     'destination_phone': '+5551998158628',
#     'protocol': 536124,
#     'answered_at': '2025-11-19T11:07:37.449000Z',
#     'hangup_cause': 2,
#     'service_duration': 65,
#     'has_audio': True,
#     'call_recording_status': 1,
#     'audio_link': '/api/v1/campaign_completed_calls/11019640/audio'},
#    'relationships': {'campaign': {'data': {'type': 'campaigns', 'id': '5'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019640/relationships/campaign',
#       'related': '/api/v1/campaign_completed_calls/11019640/campaign'}},
#     'campaign_list': {'data': {'type': 'campaign_lists', 'id': '650'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019640/relationships/campaign_list',
#       'related': '/api/v1/campaign_completed_calls/11019640/campaign_list'}},
#     'campaign_contact': {'data': {'type': 'campaign_contacts',
#       'id': '9168585'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019640/relationships/campaign_contact',
#       'related': '/api/v1/campaign_completed_calls/11019640/campaign_contact'}},
#     'customer': {'links': {'self': '/api/v1/campaign_completed_calls/11019640/relationships/customer',
#       'related': '/api/v1/campaign_completed_calls/11019640/customer'}},
#     'qualification': {'data': {'type': 'qualifications', 'id': '30005'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019640/relationships/qualification',
#       'related': '/api/v1/campaign_completed_calls/11019640/qualification'}},
#     'agent': {'data': {'type': 'users', 'id': '10'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019640/relationships/agent',
#       'related': '/api/v1/campaign_completed_calls/11019640/agent'}},
#     'transcriptions': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11019640/relationships/transcriptions',
#       'related': '/api/v1/campaign_completed_calls/11019640/transcriptions'}},
#     'tags': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11019640/relationships/tags',
#       'related': '/api/v1/campaign_completed_calls/11019640/tags'}}},
#    'links': {'self': '/api/v1/campaign_completed_calls/11019640'}},
#   {'type': 'campaign_completed_calls',
#    'id': '11019692',
#    'attributes': {'started_at': '2025-11-19T11:09:58.994000Z',
#     'ended_at': '2025-11-19T11:10:48.094000Z',
#     'duration': 49,
#     'destination_phone': '+5588996263154',
#     'protocol': 536125,
#     'answered_at': '2025-11-19T11:10:19.534000Z',
#     'hangup_cause': 1,
#     'service_duration': 29,
#     'has_audio': True,
#     'call_recording_status': 1,
#     'audio_link': '/api/v1/campaign_completed_calls/11019692/audio'},
#    'relationships': {'campaign': {'data': {'type': 'campaigns', 'id': '5'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019692/relationships/campaign',
#       'related': '/api/v1/campaign_completed_calls/11019692/campaign'}},
#     'campaign_list': {'data': {'type': 'campaign_lists', 'id': '650'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019692/relationships/campaign_list',
#       'related': '/api/v1/campaign_completed_calls/11019692/campaign_list'}},
#     'campaign_contact': {'data': {'type': 'campaign_contacts',
#       'id': '9168644'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019692/relationships/campaign_contact',
#       'related': '/api/v1/campaign_completed_calls/11019692/campaign_contact'}},
#     'customer': {'links': {'self': '/api/v1/campaign_completed_calls/11019692/relationships/customer',
#       'related': '/api/v1/campaign_completed_calls/11019692/customer'}},
#     'qualification': {'data': {'type': 'qualifications', 'id': '30005'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019692/relationships/qualification',
#       'related': '/api/v1/campaign_completed_calls/11019692/qualification'}},
#     'agent': {'data': {'type': 'users', 'id': '10'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019692/relationships/agent',
#       'related': '/api/v1/campaign_completed_calls/11019692/agent'}},
#     'transcriptions': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11019692/relationships/transcriptions',
#       'related': '/api/v1/campaign_completed_calls/11019692/transcriptions'}},
#     'tags': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11019692/relationships/tags',
#       'related': '/api/v1/campaign_completed_calls/11019692/tags'}}},
#    'links': {'self': '/api/v1/campaign_completed_calls/11019692'}},
#   {'type': 'campaign_completed_calls',
#    'id': '11019714',
#    'attributes': {'started_at': '2025-11-19T11:11:08.990000Z',
#     'ended_at': '2025-11-19T11:11:35.990000Z',
#     'duration': 27,
#     'destination_phone': '+5517996772991',
#     'protocol': 536126,
#     'answered_at': '2025-11-19T11:11:26.870000Z',
#     'hangup_cause': 1,
#     'service_duration': 10,
#     'has_audio': True,
#     'call_recording_status': 1,
#     'audio_link': '/api/v1/campaign_completed_calls/11019714/audio'},
#    'relationships': {'campaign': {'data': {'type': 'campaigns', 'id': '5'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019714/relationships/campaign',
#       'related': '/api/v1/campaign_completed_calls/11019714/campaign'}},
#     'campaign_list': {'data': {'type': 'campaign_lists', 'id': '650'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019714/relationships/campaign_list',
#       'related': '/api/v1/campaign_completed_calls/11019714/campaign_list'}},
#     'campaign_contact': {'data': {'type': 'campaign_contacts',
#       'id': '9168673'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019714/relationships/campaign_contact',
#       'related': '/api/v1/campaign_completed_calls/11019714/campaign_contact'}},
#     'customer': {'links': {'self': '/api/v1/campaign_completed_calls/11019714/relationships/customer',
#       'related': '/api/v1/campaign_completed_calls/11019714/customer'}},
#     'qualification': {'data': {'type': 'qualifications', 'id': '30005'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019714/relationships/qualification',
#       'related': '/api/v1/campaign_completed_calls/11019714/qualification'}},
#     'agent': {'data': {'type': 'users', 'id': '10'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019714/relationships/agent',
#       'related': '/api/v1/campaign_completed_calls/11019714/agent'}},
#     'transcriptions': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11019714/relationships/transcriptions',
#       'related': '/api/v1/campaign_completed_calls/11019714/transcriptions'}},
#     'tags': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11019714/relationships/tags',
#       'related': '/api/v1/campaign_completed_calls/11019714/tags'}}},
#    'links': {'self': '/api/v1/campaign_completed_calls/11019714'}},
#   {'type': 'campaign_completed_calls',
#    'id': '11019842',
#    'attributes': {'started_at': '2025-11-19T11:15:44.012000Z',
#     'ended_at': '2025-11-19T11:16:15.892000Z',
#     'duration': 31,
#     'destination_phone': '+5511997328347',
#     'protocol': 536128,
#     'answered_at': '2025-11-19T11:16:05.252000Z',
#     'hangup_cause': 1,
#     'service_duration': 11,
#     'has_audio': True,
#     'call_recording_status': 1,
#     'audio_link': '/api/v1/campaign_completed_calls/11019842/audio'},
#    'relationships': {'campaign': {'data': {'type': 'campaigns', 'id': '5'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019842/relationships/campaign',
#       'related': '/api/v1/campaign_completed_calls/11019842/campaign'}},
#     'campaign_list': {'data': {'type': 'campaign_lists', 'id': '650'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019842/relationships/campaign_list',
#       'related': '/api/v1/campaign_completed_calls/11019842/campaign_list'}},
#     'campaign_contact': {'data': {'type': 'campaign_contacts',
#       'id': '9168804'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019842/relationships/campaign_contact',
#       'related': '/api/v1/campaign_completed_calls/11019842/campaign_contact'}},
#     'customer': {'links': {'self': '/api/v1/campaign_completed_calls/11019842/relationships/customer',
#       'related': '/api/v1/campaign_completed_calls/11019842/customer'}},
#     'qualification': {'data': {'type': 'qualifications', 'id': '30001'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019842/relationships/qualification',
#       'related': '/api/v1/campaign_completed_calls/11019842/qualification'}},
#     'agent': {'data': {'type': 'users', 'id': '10'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11019842/relationships/agent',
#       'related': '/api/v1/campaign_completed_calls/11019842/agent'}},
#     'transcriptions': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11019842/relationships/transcriptions',
#       'related': '/api/v1/campaign_completed_calls/11019842/transcriptions'}},
#     'tags': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11019842/relationships/tags',
#       'related': '/api/v1/campaign_completed_calls/11019842/tags'}}},
#    'links': {'self': '/api/v1/campaign_completed_calls/11019842'}},
#   {'type': 'campaign_completed_calls',
#    'id': '11019945',
#    'attributes': {'started_at': '2025-11-19T11:18:58.990000Z',
#     'ended_at': '2025-11-19T11:19:17.810000Z',
#     'duration': 18,
#     'destination_phone': '+5513991181616',
#     'protocol': 536129,
#     'answered_at': '2025-11-19T11:19:12.710000Z',
#     'hangup_cause': 1,
#     'service_duration': 6,
#     'has_audio': True,
#     'call_recording_status': 1,
#     'audio_link': '/api/v1/campaign_completed_calls/
}},
#   {'type': 'campaign_completed_calls',
#    'id': '11023727',
#    'attributes': {'started_at': '2025-11-19T12:05:25.986000Z',
#     'ended_at': '2025-11-19T12:06:03.086000Z',
#     'duration': 37,
#     'destination_phone': '+5531971534336',
#     'protocol': 536223,
#     'answered_at': '2025-11-19T12:05:59.726000Z',
#     'hangup_cause': 1,
#     'service_duration': 4,
#     'has_audio': True,
#     'call_recording_status': 1,
#     'audio_link': '/api/v1/campaign_completed_calls/11023727/audio'},
#    'relationships': {'campaign': {'data': {'type': 'campaigns', 'id': '5'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11023727/relationships/campaign',
#       'related': '/api/v1/campaign_completed_calls/11023727/campaign'}},
#     'campaign_list': {'data': {'type': 'campaign_lists', 'id': '650'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11023727/relationships/campaign_list',
#       'related': '/api/v1/campaign_completed_calls/11023727/campaign_list'}},
#     'campaign_contact': {'data': {'type': 'campaign_contacts',
#       'id': '9173000'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11023727/relationships/campaign_contact',
#       'related': '/api/v1/campaign_completed_calls/11023727/campaign_contact'}},
#     'customer': {'links': {'self': '/api/v1/campaign_completed_calls/11023727/relationships/customer',
#       'related': '/api/v1/campaign_completed_calls/11023727/customer'}},
#     'qualification': {'data': {'type': 'qualifications', 'id': '30005'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11023727/relationships/qualification',
#       'related': '/api/v1/campaign_completed_calls/11023727/qualification'}},
#     'agent': {'data': {'type': 'users', 'id': '5'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11023727/relationships/agent',
#       'related': '/api/v1/campaign_completed_calls/11023727/agent'}},
#     'transcriptions': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11023727/relationships/transcriptions',
#       'related': '/api/v1/campaign_completed_calls/11023727/transcriptions'}},
#     'tags': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11023727/relationships/tags',
#       'related': '/api/v1/campaign_completed_calls/11023727/tags'}}},
#    'links': {'self': '/api/v1/campaign_completed_calls/11023727'}},
#   {'type': 'campaign_completed_calls',
#    'id': '11023794',
#    'attributes': {'started_at': '2025-11-19T12:05:54.993000Z',
#     'ended_at': '2025-11-19T12:06:35.013000Z',
#     'duration': 40,
#     'destination_phone': '+5527998411046',
#     'protocol': 536224,
#     'answered_at': '2025-11-19T12:06:12.613000Z',
#     'hangup_cause': 2,
#     'service_duration': 23,
#     'has_audio': True,
#     'call_recording_status': 1,
#     'audio_link': '/api/v1/campaign_completed_calls/11023794/audio'},
#    'relationships': {'campaign': {'data': {'type': 'campaigns', 'id': '5'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11023794/relationships/campaign',
#       'related': '/api/v1/campaign_completed_calls/11023794/campaign'}},
#     'campaign_list': {'data': {'type': 'campaign_lists', 'id': '650'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11023794/relationships/campaign_list',
#       'related': '/api/v1/campaign_completed_calls/11023794/campaign_list'}},
#     'campaign_contact': {'data': {'type': 'campaign_contacts',
#       'id': '9173051'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11023794/relationships/campaign_contact',
#       'related': '/api/v1/campaign_completed_calls/11023794/campaign_contact'}},
#     'customer': {'links': {'self': '/api/v1/campaign_completed_calls/11023794/relationships/customer',
#       'related': '/api/v1/campaign_completed_calls/11023794/customer'}},
#     'qualification': {'data': {'type': 'qualifications', 'id': '30005'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11023794/relationships/qualification',
#       'related': '/api/v1/campaign_completed_calls/11023794/qualification'}},
#     'agent': {'data': {'type': 'users', 'id': '12'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11023794/relationships/agent',
#       'related': '/api/v1/campaign_completed_calls/11023794/agent'}},
#     'transcriptions': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11023794/relationships/transcriptions',
#       'related': '/api/v1/campaign_completed_calls/11023794/transcriptions'}},
#     'tags': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11023794/relationships/tags',
#       'related': '/api/v1/campaign_completed_calls/11023794/tags'}}},
#    'links': {'self': '/api/v1/campaign_completed_calls/11023794'}},
#   {'type': 'campaign_completed_calls',
#    'id': '11024024',
#    'attributes': {'started_at': '2025-11-19T12:07:05.009000Z',
#     'ended_at': '2025-11-19T12:08:24.309000Z',
#     'duration': 79,
#     'destination_phone': '+5511957856087',
#     'protocol': 536225,
#     'answered_at': '2025-11-19T12:07:21.389000Z',
#     'hangup_cause': 2,
#     'service_duration': 63,
#     'has_audio': True,
#     'call_recording_status': 1,
#     'audio_link': '/api/v1/campaign_completed_calls/11024024/audio'},
#    'relationships': {'campaign': {'data': {'type': 'campaigns', 'id': '5'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11024024/relationships/campaign',
#       'related': '/api/v1/campaign_completed_calls/11024024/campaign'}},
#     'campaign_list': {'data': {'type': 'campaign_lists', 'id': '650'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11024024/relationships/campaign_list',
#       'related': '/api/v1/campaign_completed_calls/11024024/campaign_list'}},
#     'campaign_contact': {'data': {'type': 'campaign_contacts',
#       'id': '9173229'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11024024/relationships/campaign_contact',
#       'related': '/api/v1/campaign_completed_calls/11024024/campaign_contact'}},
#     'customer': {'links': {'self': '/api/v1/campaign_completed_calls/11024024/relationships/customer',
#       'related': '/api/v1/campaign_completed_calls/11024024/customer'}},
#     'qualification': {'data': {'type': 'qualifications', 'id': '30001'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11024024/relationships/qualification',
#       'related': '/api/v1/campaign_completed_calls/11024024/qualification'}},
#     'agent': {'data': {'type': 'users', 'id': '25'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11024024/relationships/agent',
#       'related': '/api/v1/campaign_completed_calls/11024024/agent'}},
#     'transcriptions': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11024024/relationships/transcriptions',
#       'related': '/api/v1/campaign_completed_calls/11024024/transcriptions'}},
#     'tags': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11024024/relationships/tags',
#       'related': '/api/v1/campaign_completed_calls/11024024/tags'}}},
#    'links': {'self': '/api/v1/campaign_completed_calls/11024024'}},
#   {'type': 'campaign_completed_calls',
#    'id': '11024059',
#    'attributes': {'started_at': '2025-11-19T12:08:13.007000Z',
#     'ended_at': '2025-11-19T12:08:49.827000Z',
#     'duration': 36,
#     'destination_phone': '+5511961855004',
#     'protocol': 536227,
#     'answered_at': '2025-11-19T12:08:29.207000Z',
#     'hangup_cause': 1,
#     'service_duration': 21,
#     'has_audio': True,
#     'call_recording_status': 1,
#     'audio_link': '/api/v1/campaign_completed_calls/11024059/audio'},
#    'relationships': {'campaign': {'data': {'type': 'campaigns', 'id': '5'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11024059/relationships/campaign',
#       'related': '/api/v1/campaign_completed_calls/11024059/campaign'}},
#     'campaign_list': {'data': {'type': 'campaign_lists', 'id': '650'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11024059/relationships/campaign_list',
#       'related': '/api/v1/campaign_completed_calls/11024059/campaign_list'}},
#     'campaign_contact': {'data': {'type': 'campaign_contacts',
#       'id': '9173372'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11024059/relationships/campaign_contact',
#       'related': '/api/v1/campaign_completed_calls/11024059/campaign_contact'}},
#     'customer': {'links': {'self': '/api/v1/campaign_completed_calls/11024059/relationships/customer',
#       'related': '/api/v1/campaign_completed_calls/11024059/customer'}},
#     'qualification': {'data': {'type': 'qualifications', 'id': '30001'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11024059/relationships/qualification',
#       'related': '/api/v1/campaign_completed_calls/11024059/qualification'}},
#     'agent': {'data': {'type': 'users', 'id': '9'},
#      'links': {'self': '/api/v1/campaign_completed_calls/11024059/relationships/agent',
#       'related': '/api/v1/campaign_completed_calls/11024059/agent'}},
#     'transcriptions': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11024059/relationships/transcriptions',
#       'related': '/api/v1/campaign_completed_calls/11024059/transcriptions'}},
#     'tags': {'data': [],
#      'links': {'self': '/api/v1/campaign_completed_calls/11024059/relationships/tags',
#       'related': '/api/v1/campaign_completed_calls/11024059/tags'}}},
#    'links': {'self': '/api/v1/campaign_completed_calls/11024059'}}]}
